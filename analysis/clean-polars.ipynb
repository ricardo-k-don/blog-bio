# %%
import polars as pl

# %% [markdown]
# ## Read & Info
#
# ### Read tabular data

# %%
user_cols = ["user_id", "age", "gender", "occupation", "zip_code"]
users = pl.read_csv("data/movie.user", sep="|", new_columns=user_cols, has_header=False)

# %%
# examine the first 5 rows
users.head()
# Out:
# shape: (5, 5)
# ┌─────────┬─────┬────────┬────────────┬──────────┐
# │ user_id ┆ age ┆ gender ┆ occupation ┆ zip_code │
# │ ---     ┆ --- ┆ ---    ┆ ---        ┆ ---      │
# │ i64     ┆ i64 ┆ str    ┆ str        ┆ str      │
# ╞═════════╪═════╪════════╪════════════╪══════════╡
# │ 1       ┆ 24  ┆ M      ┆ technician ┆ 85711    │
# │ 2       ┆ 53  ┆ F      ┆ other      ┆ 94043    │
# │ 3       ┆ 23  ┆ M      ┆ writer     ┆ 32067    │
# │ 4       ┆ 24  ┆ M      ┆ technician ┆ 43537    │
# │ 5       ┆ 33  ┆ F      ┆ other      ┆ 15213    │
# └─────────┴─────┴────────┴────────────┴──────────┘
